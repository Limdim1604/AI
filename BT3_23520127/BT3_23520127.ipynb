# %%
#git clone https://github.com/likr/kplib.git

# %%
import os
import time
import glob
import pandas as pd
from ortools.algorithms.python import knapsack_solver

# Thời gian giới hạn cho mỗi bài test (giây)
TIME_LIMIT_SECONDS = 160

def read_kp_file(file_path):
    """Đọc file test case Knapsack."""
    with open(file_path, 'r') as f:
        lines = f.readlines()
    
    # Đọc số lượng items và sức chứa
    n = int(lines[1].strip())
    capacity = int(lines[2].strip())
    
    # Đọc trọng lượng và giá trị
    weights = []
    values = []
    for i in range(4, 4 + n):
        parts = lines[i].strip().split()
        values.append(int(parts[0]))
        weights.append(int(parts[1]))
    
    return n, capacity, values, weights

def solve_knapsack(file_path):
    """Giải bài toán Knapsack cho một file test case."""
    try:
        n, capacity, values, weights_list = read_kp_file(file_path)
        weights = [weights_list]  # OR-Tools yêu cầu list của lists
        capacities = [capacity]
        
        # Tạo solver
        solver = knapsack_solver.KnapsackSolver(
            knapsack_solver.SolverType.KNAPSACK_MULTIDIMENSION_BRANCH_AND_BOUND_SOLVER,
            "KnapsackSolver"
        )
        
        # Thiết lập thời gian giới hạn
        solver.set_time_limit(TIME_LIMIT_SECONDS)
        
        # Khởi tạo solver với dữ liệu
        solver.init(values, weights, capacities)
        
        # Bắt đầu tính thời gian
        start_time = time.time()
        
        # Giải bài toán
        computed_value = solver.solve()
        
        # Kết thúc tính thời gian
        elapsed_time = time.time() - start_time
        
        # Xác định tính tối ưu của lời giải
        # Nếu thời gian chạy đã đạt tới giới hạn, coi là không tối ưu
        is_optimal = elapsed_time < (TIME_LIMIT_SECONDS - 0.1)
        
        
        # Tìm các items được đưa vào túi và tính tổng trọng lượng
        packed_items = []
        total_weight = 0
        for i in range(len(values)):
            if solver.best_solution_contains(i):
                packed_items.append(i)
                total_weight += weights[0][i]
        
        return {
            'testcase': os.path.relpath(file_path, os.path.join(os.getcwd(), 'kplib')),
            'Nitems': n,
            'value': computed_value,
            'weight': total_weight,
            'time': f"{elapsed_time:.6f}",
            'optimal': is_optimal
        }
        
    except Exception as e:
        print(f"Error processing {file_path}: {e}")
        return {
            'testcase': os.path.relpath(file_path, os.path.join(os.getcwd(), 'kplib')),
            'Nitems': -1,
            'value': -1,
            'weight': -1,
            'time': -1,
            'optimal': False
        }

def find_test_cases(kplib_dir):
    """Tìm các test cases từ các nhóm khác nhau và kích thước khác nhau."""
    # Kích thước items cần lấy
    item_sizes = ['00050', '00100', '00200', '00500', '01000', '02000', '05000', '10000']
    
    # Danh sách test cases được chọn
    selected_test_cases = []
    
    # Lặp qua các nhóm từ 00 đến 12
    for group_num in range(13):
        group_name = f"{group_num:02d}"
        
        # Xác định tên đầy đủ của thư mục nhóm
        group_paths = []
        for folder in os.listdir(kplib_dir):
            if folder.startswith(group_name):
                group_paths.append(os.path.join(kplib_dir, folder))
        
        if not group_paths:
            print(f"Warning: No folder found for group {group_name}")
            continue
            
        group_dir = group_paths[0]
        
        # Lặp qua các kích thước
        for size in item_sizes:
            size_path = os.path.join(group_dir, "n" + size)
            
            # Kiểm tra thư mục kích thước có tồn tại
            if not os.path.exists(size_path):
                continue
                
            # Tìm các instances trong R01000 hoặc R10000
            r_folders = [f for f in os.listdir(size_path) if f.startswith("R")]
            
            # Lấy một test case từ mỗi R folder
            for r_folder in r_folders:
                r_path = os.path.join(size_path, r_folder)
                if os.path.isdir(r_path):
                    # Lấy file 16.kp từ thư mục R
                    kp_files = [f for f in os.listdir(r_path) if f.endswith(".kp")]
                    if kp_files:
                        test_file = os.path.join(r_path, kp_files[16])
                        selected_test_cases.append(test_file)
    
    return selected_test_cases


def main():
    print("Starting Knapsack Problem Solver with OR-Tools...")
    
    # Đường dẫn đến thư mục kplib
    kplib_dir = os.path.join(os.getcwd(), 'kplib')
    
    # Kiểm tra xem thư mục kplib có tồn tại không
    if not os.path.exists(kplib_dir):
        print(f"Error: kplib directory not found at {kplib_dir}")
        return
    
    print(f"Found kplib directory at {kplib_dir}")
    
    # Tìm test cases
    test_cases = find_test_cases(kplib_dir)
    print(f"Found {len(test_cases)} test cases")
    
    # Kiểm tra nếu không tìm thấy test cases nào
    if not test_cases:
        print("No test cases found. Please check if kplib is properly cloned.")
        return
    
    # Kết quả
    results = []
    
    # Giải từng test case
    for i, test_file in enumerate(test_cases):
        print(f"Processing test case {i+1}/{len(test_cases)}: {os.path.basename(test_file)}")
        result = solve_knapsack(test_file)
        results.append(result)
        
        # In kết quả trung gian
        print(f"  Value: {result['value']}, Weight: {result['weight']}, Time: {result['time']}s, Optimal: {result['optimal']}")
    
    # Tạo DataFrame từ kết quả
    results_df = pd.DataFrame(results)
    
    # Lưu kết quả vào file CSV
    results_df.to_csv('knapsack_results.csv', index=False)
    print("Results saved to knapsack_results.csv")
    

    
    # In báo cáo trong terminal
    print("\n===== KNAPSACK TEST RESULTS =====")
    print(results_df)
    

if __name__ == "__main__":
    main()
# Out:
# load c:\Users\ACER\AppData\Local\Programs\Python\Python312\Lib\site-packages\ortools\.libs\zlib1.dll...
# load c:\Users\ACER\AppData\Local\Programs\Python\Python312\Lib\site-packages\ortools\.libs\abseil_dll.dll...
# load c:\Users\ACER\AppData\Local\Programs\Python\Python312\Lib\site-packages\ortools\.libs\utf8_validity.dll...
# load c:\Users\ACER\AppData\Local\Programs\Python\Python312\Lib\site-packages\ortools\.libs\re2.dll...
# load c:\Users\ACER\AppData\Local\Programs\Python\Python312\Lib\site-packages\ortools\.libs\libprotobuf.dll...
# load c:\Users\ACER\AppData\Local\Programs\Python\Python312\Lib\site-packages\ortools\.libs\highs.dll...
# load c:\Users\ACER\AppData\Local\Programs\Python\Python312\Lib\site-packages\ortools\.libs\ortools.dll...
# Starting Knapsack Problem Solver with OR-Tools...
# Found kplib directory at d:\NĂM 2 KÌ 2\AI\ORtool\kplib
# Found 208 test cases
# Processing test case 1/208: s016.kp
#   Value: 19232, Weight: 10474, Time: 0.000000s, Optimal: True
# Processing test case 2/208: s016.kp
#   Value: 192182, Weight: 104590, Time: 0.000000s, Optimal: True
# Processing test case 3/208: s016.kp
#   Value: 36378, Weight: 24080, Time: 0.000000s, Optimal: True
# Processing test case 4/208: s016.kp
#   Value: 363530, Weight: 240546, Time: 0.000000s, Optimal: True
# Processing test case 5/208: s016.kp
#   Value: 78006, Weight: 48276, Time: 0.000000s, Optimal: True
# Processing test case 6/208: s016.kp
#   Value: 779759, Weight: 482347, Time: 0.000000s, Optimal: True
# Processing test case 7/208: s016.kp
#   Value: 195312, Weight: 125173, Time: 0.000000s, Optimal: True
# Processing test case 8/208: s016.kp
#   Value: 1952024, Weight: 1250612, Time: 0.000000s, Optimal: True
# Processing test case 9/208: s016.kp
#   Value: 398473, Weight: 255665, Time: 0.000000s, Optimal: True
# Processing test case 10/208: s016.kp
#   Value: 3982239, Weight: 2554418, Time: 0.000996s, Optimal: True
# Processing test case 11/208: s016.kp
#   Value: 814319, Weight: 504245, Time: 0.000000s, Optimal: True
# Processing test case 12/208: s016.kp
#   Value: 8138485, Weight: 5038052, Time: 0.001003s, Optimal: True
# Processing test case 13/208: s016.kp
#   Value: 2064184, Weight: 1225662, Time: 0.001005s, Optimal: True
# Processing test case 14/208: s016.kp
#   Value: 20629786, Weight: 12245551, Time: 0.002990s, Optimal: True
# Processing test case 15/208: s016.kp
#   Value: 4047923, Weight: 2492615, Time: 0.004548s, Optimal: True
# Processing test case 16/208: s016.kp
#   Value: 40455498, Weight: 24904113, Time: 0.006064s, Optimal: True
# Processing test case 17/208: s016.kp
#   Value: 12900, Weight: 11928, Time: 0.001078s, Optimal: True
# Processing test case 18/208: s016.kp
#   Value: 128854, Weight: 119176, Time: 0.000000s, Optimal: True
# Processing test case 19/208: s016.kp
#   Value: 24998, Weight: 22466, Time: 0.000000s, Optimal: True
# Processing test case 20/208: s016.kp
#   Value: 249634, Weight: 224427, Time: 0.000000s, Optimal: True
# Processing test case 21/208: s016.kp
#   Value: 51888, Weight: 46558, Time: 0.000000s, Optimal: True
# Processing test case 22/208: s016.kp
#   Value: 518217, Weight: 465143, Time: 0.000000s, Optimal: True
# Processing test case 23/208: s016.kp
#   Value: 131694, Weight: 118266, Time: 0.001058s, Optimal: True
# Processing test case 24/208: s016.kp
#   Value: 1315267, Weight: 1181593, Time: 0.000000s, Optimal: True
# Processing test case 25/208: s016.kp
#   Value: 271835, Weight: 243448, Time: 0.000000s, Optimal: True
# Processing test case 26/208: s016.kp
#   Value: 2714816, Weight: 2432289, Time: 0.000992s, Optimal: True
# Processing test case 27/208: s016.kp
#   Value: 553379, Weight: 499114, Time: 0.008999s, Optimal: True
# Processing test case 28/208: s016.kp
#   Value: 5526838, Weight: 4986708, Time: 0.007317s, Optimal: True
# Processing test case 29/208: s016.kp
#   Value: 1381888, Weight: 1252946, Time: 0.083811s, Optimal: True
# Processing test case 30/208: s016.kp
#   Value: 13801485, Weight: 12518336, Time: 0.007004s, Optimal: True
# Processing test case 31/208: s016.kp
#   Value: 2741205, Weight: 2478609, Time: 0.441090s, Optimal: True
# Processing test case 32/208: s016.kp
#   Value: 27378034, Weight: 24763892, Time: 0.012283s, Optimal: True
# Processing test case 33/208: s016.kp
#   Value: 15429, Weight: 11929, Time: 0.000000s, Optimal: True
# Processing test case 34/208: s016.kp
#   Value: 154182, Weight: 119182, Time: 0.000000s, Optimal: True
# Processing test case 35/208: s016.kp
#   Value: 29666, Weight: 22466, Time: 0.000000s, Optimal: True
# Processing test case 36/208: s016.kp
#   Value: 296428, Weight: 224428, Time: 0.000000s, Optimal: True
# Processing test case 37/208: s016.kp
#   Value: 60759, Weight: 46559, Time: 160.087576s, Optimal: False
# Processing test case 38/208: s016.kp
#   Value: 607155, Weight: 465155, Time: 160.012739s, Optimal: False
# Processing test case 39/208: s016.kp
#   Value: 154166, Weight: 118266, Time: 160.020838s, Optimal: False
# Processing test case 40/208: s016.kp
#   Value: 1540595, Weight: 1181595, Time: 160.016821s, Optimal: False
# Processing test case 41/208: s016.kp
#   Value: 314348, Weight: 243448, Time: 160.069877s, Optimal: False
# Processing test case 42/208: s016.kp
#   Value: 3139593, Weight: 2430593, Time: 160.014133s, Optimal: False
# Processing test case 43/208: s016.kp
#   Value: 639864, Weight: 498964, Time: 160.011886s, Optimal: False
# Processing test case 44/208: s016.kp
#   Value: 6392099, Weight: 4983099, Time: 160.002279s, Optimal: False
# Processing test case 45/208: s016.kp
#   Value: 1603990, Weight: 1252590, Time: 159.945733s, Optimal: False
# Processing test case 46/208: s016.kp
#   Value: 16029061, Weight: 12514061, Time: 159.950682s, Optimal: False
# Processing test case 47/208: s016.kp
#   Value: 3183204, Weight: 2478204, Time: 159.756011s, Optimal: True
# Processing test case 48/208: s016.kp
#   Value: 31808899, Weight: 24757899, Time: 159.757114s, Optimal: True
# Processing test case 49/208: s016.kp
#   Value: 12804, Weight: 14404, Time: 0.000000s, Optimal: True
# Processing test case 50/208: s016.kp
#   Value: 127931, Weight: 143931, Time: 0.000984s, Optimal: True
# Processing test case 51/208: s016.kp
#   Value: 24317, Weight: 27417, Time: 78.616043s, Optimal: True
# Processing test case 52/208: s016.kp
#   Value: 242934, Weight: 273934, Time: 160.000653s, Optimal: False
# Processing test case 53/208: s016.kp
#   Value: 50260, Weight: 56460, Time: 160.093446s, Optimal: False
# Processing test case 54/208: s016.kp
#   Value: 502167, Weight: 564167, Time: 160.017032s, Optimal: False
# Processing test case 55/208: s016.kp
#   Value: 127688, Weight: 142788, Time: 160.089780s, Optimal: False
# Processing test case 56/208: s016.kp
#   Value: 1276243, Weight: 1427243, Time: 160.018535s, Optimal: False
# Processing test case 57/208: s016.kp
#   Value: 261704, Weight: 292704, Time: 160.033904s, Optimal: False
# Processing test case 58/208: s016.kp
#   Value: 2615642, Weight: 2925642, Time: 160.021113s, Optimal: False
# Processing test case 59/208: s016.kp
#   Value: 535324, Weight: 598124, Time: 0.000000s, Optimal: True
# Processing test case 60/208: s016.kp
#   Value: 5348807, Weight: 5976807, Time: 160.045429s, Optimal: False
# Processing test case 61/208: s016.kp
#   Value: 1342746, Weight: 1500446, Time: 159.987336s, Optimal: False
# Processing test case 62/208: s016.kp
#   Value: 13413442, Weight: 14989442, Time: 159.982930s, Optimal: False
# Processing test case 63/208: s016.kp
#   Value: 2659699, Weight: 2973499, Time: 159.895643s, Optimal: True
# Processing test case 64/208: s016.kp
#   Value: 26576055, Weight: 29713055, Time: 159.903626s, Optimal: False
# Processing test case 65/208: s016.kp
#   Value: 15416, Weight: 11928, Time: 0.000000s, Optimal: True
# Processing test case 66/208: s016.kp
#   Value: 154059, Weight: 119182, Time: 0.000000s, Optimal: True
# Processing test case 67/208: s016.kp
#   Value: 29661, Weight: 22466, Time: 0.000000s, Optimal: True
# Processing test case 68/208: s016.kp
#   Value: 296373, Weight: 224428, Time: 0.000000s, Optimal: True
# Processing test case 69/208: s016.kp
#   Value: 60769, Weight: 46559, Time: 160.058294s, Optimal: False
# Processing test case 70/208: s016.kp
#   Value: 607171, Weight: 465118, Time: 160.014999s, Optimal: False
# Processing test case 71/208: s016.kp
#   Value: 154177, Weight: 118266, Time: 2.425919s, Optimal: True
# Processing test case 72/208: s016.kp
#   Value: 1540743, Weight: 1181594, Time: 160.001878s, Optimal: False
# Processing test case 73/208: s016.kp
#   Value: 314437, Weight: 243449, Time: 160.006495s, Optimal: False
# Processing test case 74/208: s016.kp
#   Value: 3141476, Weight: 2431767, Time: 160.009850s, Optimal: False
# Processing test case 75/208: s016.kp
#   Value: 640048, Weight: 499114, Time: 160.045292s, Optimal: False
# Processing test case 76/208: s016.kp
#   Value: 6393968, Weight: 4984562, Time: 160.004087s, Optimal: False
# Processing test case 77/208: s016.kp
#   Value: 1604129, Weight: 1252610, Time: 159.949310s, Optimal: False
# Processing test case 78/208: s016.kp
#   Value: 16032360, Weight: 12516574, Time: 159.954023s, Optimal: False
# Processing test case 79/208: s016.kp
#   Value: 3183785, Weight: 2478609, Time: 159.756040s, Optimal: True
# Processing test case 80/208: s016.kp
#   Value: 31813728, Weight: 24761320, Time: 159.762659s, Optimal: True
# Processing test case 81/208: s016.kp
#   Value: 11929, Weight: 11929, Time: 0.000000s, Optimal: True
# Processing test case 82/208: s016.kp
#   Value: 119182, Weight: 119182, Time: 0.000000s, Optimal: True
# Processing test case 83/208: s016.kp
#   Value: 22466, Weight: 22466, Time: 0.000000s, Optimal: True
# Processing test case 84/208: s016.kp
#   Value: 224429, Weight: 224429, Time: 0.000000s, Optimal: True
# Processing test case 85/208: s016.kp
#   Value: 46559, Weight: 46559, Time: 0.000000s, Optimal: True
# Processing test case 86/208: s016.kp
#   Value: 465157, Weight: 465157, Time: 0.003211s, Optimal: True
# Processing test case 87/208: s016.kp
#   Value: 118266, Weight: 118266, Time: 0.000000s, Optimal: True
# Processing test case 88/208: s016.kp
#   Value: 1181595, Weight: 1181595, Time: 0.002999s, Optimal: True
# Processing test case 89/208: s016.kp
#   Value: 243449, Weight: 243449, Time: 0.000000s, Optimal: True
# Processing test case 90/208: s016.kp
#   Value: 2432289, Weight: 2432289, Time: 0.002000s, Optimal: True
# Processing test case 91/208: s016.kp
#   Value: 499114, Weight: 499114, Time: 0.000998s, Optimal: True
# Processing test case 92/208: s016.kp
#   Value: 4986708, Weight: 4986708, Time: 0.000000s, Optimal: True
# Processing test case 93/208: s016.kp
#   Value: 1252946, Weight: 1252946, Time: 0.002050s, Optimal: True
# Processing test case 94/208: s016.kp
#   Value: 12518337, Weight: 12518337, Time: 0.009286s, Optimal: True
# Processing test case 95/208: s016.kp
#   Value: 2478609, Weight: 2478609, Time: 0.002632s, Optimal: True
# Processing test case 96/208: s016.kp
#   Value: 24763893, Weight: 24763893, Time: 0.004300s, Optimal: True
# Processing test case 97/208: s016.kp
#   Value: 17384, Weight: 2401073, Time: 0.016876s, Optimal: True
# Processing test case 98/208: s016.kp
#   Value: 17384, Weight: 2401073, Time: 0.015595s, Optimal: True
# Processing test case 99/208: s016.kp
#   Value: 34448, Weight: 4902554, Time: 0.103662s, Optimal: True
# Processing test case 100/208: s016.kp
#   Value: 34448, Weight: 4902554, Time: 0.101830s, Optimal: True
# Processing test case 101/208: s016.kp
#   Value: 71538, Weight: 9904917, Time: 0.000000s, Optimal: True
# Processing test case 102/208: s016.kp
#   Value: 71538, Weight: 9904917, Time: 0.000000s, Optimal: True
# Processing test case 103/208: s016.kp
#   Value: 182355, Weight: 24712578, Time: 160.024057s, Optimal: False
# Processing test case 104/208: s016.kp
#   Value: 182355, Weight: 24712578, Time: 160.019047s, Optimal: False
# Processing test case 105/208: s016.kp
#   Value: 370842, Weight: 49525893, Time: 0.071626s, Optimal: True
# Processing test case 106/208: s016.kp
#   Value: 370842, Weight: 49525893, Time: 0.065800s, Optimal: True
# Processing test case 107/208: s016.kp
#   Value: 753943, Weight: 99050939, Time: 160.045185s, Optimal: False
# Processing test case 108/208: s016.kp
#   Value: 753943, Weight: 99050939, Time: 160.023556s, Optimal: False
# Processing test case 109/208: s016.kp
#   Value: 1885243, Weight: 247620341, Time: 159.966260s, Optimal: False
# Processing test case 110/208: s016.kp
#   Value: 1885243, Weight: 247620341, Time: 159.972214s, Optimal: False
# Processing test case 111/208: s016.kp
#   Value: 3741911, Weight: 495249101, Time: 159.829281s, Optimal: True
# Processing test case 112/208: s016.kp
#   Value: 3741911, Weight: 495249101, Time: 159.832377s, Optimal: True
# Processing test case 113/208: s016.kp
#   Value: 5028, Weight: 4764, Time: 0.426180s, Optimal: True
# Processing test case 114/208: s016.kp
#   Value: 51352, Weight: 48775, Time: 0.079125s, Optimal: True
# Processing test case 115/208: s016.kp
#   Value: 10922, Weight: 10160, Time: 0.249830s, Optimal: True
# Processing test case 116/208: s016.kp
#   Value: 111180, Weight: 103530, Time: 0.894044s, Optimal: True
# Processing test case 117/208: s016.kp
#   Value: 21637, Weight: 20207, Time: 152.132630s, Optimal: True
# Processing test case 118/208: s016.kp
#   Value: 220088, Weight: 206195, Time: 160.084928s, Optimal: False
# Processing test case 119/208: s016.kp
#   Value: 55126, Weight: 51280, Time: 160.056337s, Optimal: False
# Processing test case 120/208: s016.kp
#   Value: 561568, Weight: 522928, Time: 160.081155s, Optimal: False
# Processing test case 121/208: s016.kp
#   Value: 111542, Weight: 103760, Time: 160.337414s, Optimal: False
# Processing test case 122/208: s016.kp
#   Value: 1135780, Weight: 1057630, Time: 160.071371s, Optimal: False
# Processing test case 123/208: s016.kp
#   Value: 225363, Weight: 209640, Time: 160.046991s, Optimal: False
# Processing test case 124/208: s016.kp
#   Value: 2295104, Weight: 2137184, Time: 160.034406s, Optimal: False
# Processing test case 125/208: s016.kp
#   Value: 559344, Weight: 520320, Time: 159.981934s, Optimal: False
# Processing test case 126/208: s016.kp
#   Value: 5696340, Weight: 5304390, Time: 159.982345s, Optimal: False
# Processing test case 127/208: s016.kp
#   Value: 1128223, Weight: 1049517, Time: 159.862023s, Optimal: True
# Processing test case 128/208: s016.kp
#   Value: 11489908, Weight: 10699318, Time: 159.866599s, Optimal: True
# Processing test case 129/208: s016.kp
#   Value: 8016, Weight: 4587, Time: 0.000000s, Optimal: True
# Processing test case 130/208: s016.kp
#   Value: 78844, Weight: 46792, Time: 0.002976s, Optimal: True
# Processing test case 131/208: s016.kp
#   Value: 16984, Weight: 9898, Time: 17.830142s, Optimal: True
# Processing test case 132/208: s016.kp
#   Value: 167644, Weight: 100876, Time: 13.130417s, Optimal: True
# Processing test case 133/208: s016.kp
#   Value: 33848, Weight: 19541, Time: 160.071535s, Optimal: False
# Processing test case 134/208: s016.kp
#   Value: 333378, Weight: 199056, Time: 160.127065s, Optimal: False
# Processing test case 135/208: s016.kp
#   Value: 85760, Weight: 49745, Time: 160.045552s, Optimal: False
# Processing test case 136/208: s016.kp
#   Value: 845490, Weight: 506616, Time: 160.103286s, Optimal: False
# Processing test case 137/208: s016.kp
#   Value: 173008, Weight: 101356, Time: 160.062776s, Optimal: False
# Processing test case 138/208: s016.kp
#   Value: 1708006, Weight: 1032368, Time: 160.021748s, Optimal: False
# Processing test case 139/208: s016.kp
#   Value: 349648, Weight: 204691, Time: 160.023502s, Optimal: False
# Processing test case 140/208: s016.kp
#   Value: 3451458, Weight: 2084660, Time: 160.005705s, Optimal: False
# Processing test case 141/208: s016.kp
#   Value: 868432, Weight: 507034, Time: 159.969704s, Optimal: False
# Processing test case 142/208: s016.kp
#   Value: 8570360, Weight: 5164928, Time: 159.966198s, Optimal: False
# Processing test case 143/208: s016.kp
#   Value: 1751696, Weight: 1022627, Time: 159.850858s, Optimal: True
# Processing test case 144/208: s016.kp
#   Value: 17287214, Weight: 10417092, Time: 159.839799s, Optimal: True
# Processing test case 145/208: s016.kp
#   Value: 19140, Weight: 4640, Time: 0.000000s, Optimal: True
# Processing test case 146/208: s016.kp
#   Value: 191340, Weight: 47340, Time: 0.000220s, Optimal: True
# Processing test case 147/208: s016.kp
#   Value: 40029, Weight: 9929, Time: 44.994821s, Optimal: True
# Processing test case 148/208: s016.kp
#   Value: 401208, Weight: 101208, Time: 3.391796s, Optimal: True
# Processing test case 149/208: s016.kp
#   Value: 79794, Weight: 19594, Time: 160.082486s, Optimal: False
# Processing test case 150/208: s016.kp
#   Value: 798712, Weight: 199712, Time: 160.047276s, Optimal: False
# Processing test case 151/208: s016.kp
#   Value: 201366, Weight: 49766, Time: 160.050948s, Optimal: False
# Processing test case 152/208: s016.kp
#   Value: 2017052, Weight: 507052, Time: 160.061133s, Optimal: False
# Processing test case 153/208: s016.kp
#   Value: 404998, Weight: 101398, Time: 160.033233s, Optimal: False
# Processing test case 154/208: s016.kp
#   Value: 4059028, Weight: 1033028, Time: 157.470714s, Optimal: True
# Processing test case 155/208: s016.kp
#   Value: 817971, Weight: 204571, Time: 160.012110s, Optimal: False
# Processing test case 156/208: s016.kp
#   Value: 8195684, Weight: 2083684, Time: 160.026704s, Optimal: False
# Processing test case 157/208: s016.kp
#   Value: 2033779, Weight: 506979, Time: 159.973639s, Optimal: False
# Processing test case 158/208: s016.kp
#   Value: 20377716, Weight: 5164716, Time: 159.969748s, Optimal: False
# Processing test case 159/208: s016.kp
#   Value: 4102769, Weight: 1022669, Time: 159.843381s, Optimal: True
# Processing test case 160/208: s016.kp
#   Value: 41105312, Weight: 10417312, Time: 159.843622s, Optimal: True
# Processing test case 161/208: s016.kp
#   Value: 19523, Weight: 11923, Time: 0.001000s, Optimal: True
# Processing test case 162/208: s016.kp
#   Value: 193176, Weight: 119176, Time: 0.000000s, Optimal: True
# Processing test case 163/208: s016.kp
#   Value: 37964, Weight: 22464, Time: 0.411873s, Optimal: True
# Processing test case 164/208: s016.kp
#   Value: 380398, Weight: 224398, Time: 0.000000s, Optimal: True
# Processing test case 165/208: s016.kp
#   Value: 77254, Weight: 46554, Time: 160.003761s, Optimal: False
# Processing test case 166/208: s016.kp
#   Value: 777156, Weight: 465156, Time: 0.088037s, Optimal: True
# Processing test case 167/208: s016.kp
#   Value: 196666, Weight: 118266, Time: 160.075499s, Optimal: False
# Processing test case 168/208: s016.kp
#   Value: 1962583, Weight: 1181583, Time: 0.000000s, Optimal: True
# Processing test case 169/208: s016.kp
#   Value: 397844, Weight: 243444, Time: 160.029780s, Optimal: False
# Processing test case 170/208: s016.kp
#   Value: 3980286, Weight: 2432286, Time: 0.000000s, Optimal: True
# Processing test case 171/208: s016.kp
#   Value: 808210, Weight: 499110, Time: 160.011466s, Optimal: False
# Processing test case 172/208: s016.kp
#   Value: 8094280, Weight: 4986280, Time: 160.009012s, Optimal: False
# Processing test case 173/208: s016.kp
#   Value: 2025944, Weight: 1252944, Time: 159.980351s, Optimal: False
# Processing test case 174/208: s016.kp
#   Value: 20237003, Weight: 12518003, Time: 159.952357s, Optimal: False
# Processing test case 175/208: s016.kp
#   Value: 4027741, Weight: 2478541, Time: 159.769108s, Optimal: True
# Processing test case 176/208: s016.kp
#   Value: 40234308, Weight: 24762308, Time: 159.762854s, Optimal: True
# Processing test case 177/208: s016.kp
#   Value: 11922, Weight: 11929, Time: 0.000989s, Optimal: True
# Processing test case 178/208: s016.kp
#   Value: 119172, Weight: 119182, Time: 0.000999s, Optimal: True
# Processing test case 179/208: s016.kp
#   Value: 22452, Weight: 22466, Time: 0.000000s, Optimal: True
# Processing test case 180/208: s016.kp
#   Value: 224412, Weight: 224428, Time: 160.057570s, Optimal: False
# Processing test case 181/208: s016.kp
#   Value: 46533, Weight: 46559, Time: 0.000000s, Optimal: True
# Processing test case 182/208: s016.kp
#   Value: 465135, Weight: 465155, Time: 160.105424s, Optimal: False
# Processing test case 183/208: s016.kp
#   Value: 118218, Weight: 118265, Time: 159.956944s, Optimal: False
# Processing test case 184/208: s016.kp
#   Value: 1181544, Weight: 1181595, Time: 1.114978s, Optimal: True
# Processing test case 185/208: s016.kp
#   Value: 243345, Weight: 243449, Time: 160.063410s, Optimal: False
# Processing test case 186/208: s016.kp
#   Value: 2432190, Weight: 2432287, Time: 160.104682s, Optimal: False
# Processing test case 187/208: s016.kp
#   Value: 498927, Weight: 499113, Time: 160.008215s, Optimal: False
# Processing test case 188/208: s016.kp
#   Value: 4986528, Weight: 4986708, Time: 160.013547s, Optimal: False
# Processing test case 189/208: s016.kp
#   Value: 1252473, Weight: 1252946, Time: 159.976309s, Optimal: False
# Processing test case 190/208: s016.kp
#   Value: 12517860, Weight: 12518335, Time: 159.986182s, Optimal: False
# Processing test case 191/208: s016.kp
#   Value: 2477691, Weight: 2478609, Time: 159.869405s, Optimal: True
# Processing test case 192/208: s016.kp
#   Value: 24762942, Weight: 24763893, Time: 159.871587s, Optimal: True
# Processing test case 193/208: s016.kp
#   Value: 251354, Weight: 11929, Time: 0.450471s, Optimal: True
# Processing test case 194/208: s016.kp
#   Value: 7945063, Weight: 119182, Time: 1.678827s, Optimal: True
# Processing test case 195/208: s016.kp
#   Value: 473377, Weight: 22466, Time: 160.100425s, Optimal: False
# Processing test case 196/208: s016.kp
#   Value: 14961176, Weight: 224429, Time: 0.649608s, Optimal: True
# Processing test case 197/208: s016.kp
#   Value: 981039, Weight: 46559, Time: 160.100272s, Optimal: False
# Processing test case 198/208: s016.kp
#   Value: 31008897, Weight: 465157, Time: 160.085261s, Optimal: False
# Processing test case 199/208: s016.kp
#   Value: 2491974, Weight: 118266, Time: 160.081771s, Optimal: False
# Processing test case 200/208: s016.kp
#   Value: 78769019, Weight: 1181595, Time: 156.936944s, Optimal: True
# Processing test case 201/208: s016.kp
#   Value: 5129695, Weight: 243449, Time: 160.055548s, Optimal: False
# Processing test case 202/208: s016.kp
#   Value: 162144403, Weight: 2432289, Time: 158.958201s, Optimal: True
# Processing test case 203/208: s016.kp
#   Value: 10516807, Weight: 499114, Time: 160.022749s, Optimal: False
# Processing test case 204/208: s016.kp
#   Value: 332430390, Weight: 4986708, Time: 159.212533s, Optimal: True
# Processing test case 205/208: s016.kp
#   Value: 26400760, Weight: 1252946, Time: 159.979260s, Optimal: False
# Processing test case 206/208: s016.kp
#   Value: 834513615, Weight: 12518337, Time: 159.980762s, Optimal: False
# Processing test case 207/208: s016.kp
#   Value: 52226632, Weight: 2478609, Time: 159.875270s, Optimal: True
# Processing test case 208/208: s016.kp
#   Value: 1650842738, Weight: 24763893, Time: 159.882809s, Optimal: True
# Results saved to knapsack_results.csv
#
# ===== KNAPSACK TEST RESULTS =====
#                                  testcase  Nitems       value    weight  \
# 0    00Uncorrelated\n00050\R01000\s016.kp      50       19232     10474
# 1    00Uncorrelated\n00050\R10000\s016.kp      50      192182    104590
# 2    00Uncorrelated\n00100\R01000\s016.kp     100       36378     24080
# 3    00Uncorrelated\n00100\R10000\s016.kp     100      363530    240546
# 4    00Uncorrelated\n00200\R01000\s016.kp     200       78006     48276
# ..                                    ...     ...         ...       ...
# 203        12Circle\n02000\R10000\s016.kp    2000   332430390   4986708
# 204        12Circle\n05000\R01000\s016.kp    5000    26400760   1252946
# 205        12Circle\n05000\R10000\s016.kp    5000   834513615  12518337
# 206        12Circle\n10000\R01000\s016.kp   10000    52226632   2478609
# 207        12Circle\n10000\R10000\s016.kp   10000  1650842738  24763893
#
#            time  optimal
# 0      0.000000     True
# 1      0.000000     True
# 2      0.000000     True
# 3      0.000000     True
# 4      0.000000     True
# ..          ...      ...
# 203  159.212533     True
# 204  159.979260    False
# 205  159.980762    False
# 206  159.875270     True
# 207  159.882809     True
#
# [208 rows x 6 columns]
